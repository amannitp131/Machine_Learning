# %%
## import library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X=6*np.random.rand(100,1)-3
Y= 0.5* X**2 + 1.5*X +2+ np.random.randn()

## see the distribution of X and Y 
plt.scatter(X,Y,color="purple")

# %%
## do train test split

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
## lets implement simple linear regression 

from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
score=r2_score(y_true=Y_test,y_pred=regression.predict(X_test))
print(score)

## conclusion ==low accuracy
# Out:
# 0.7087691556235127

# %%
## lets visulaize this model

plt.scatter(X_train,Y_train)
plt.plot(X_train,regression.predict(X_train),color='red')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("SEE THE BEST FIT LINE DRAWN FOR OUR MODEL")
# Out:
# Text(0.5, 1.0, 'SEE THE BEST FIT LINE DRAWN FOR OUR MODEL')

# %%
## SO WE HAVE TO APPLY POLYNOMIAL LINEAR REGRESSION 

from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3,include_bias=True)
X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test)
X_train_poly
# Out:
# array([[ 1.00000000e+00,  2.42083903e+00,  5.86046160e+00,
#          1.41872342e+01],
#        [ 1.00000000e+00,  5.93442160e-01,  3.52173598e-01,
#          2.08994661e-01],
#        [ 1.00000000e+00, -4.36632556e-01,  1.90647989e-01,
#         -8.32431185e-02],
#        [ 1.00000000e+00,  2.12077301e+00,  4.49767817e+00,
#          9.53855447e+00],
#        [ 1.00000000e+00, -1.17126605e+00,  1.37186416e+00,
#         -1.60681791e+00],
#        [ 1.00000000e+00, -2.22661421e+00,  4.95781082e+00,
#         -1.10391320e+01],
#        [ 1.00000000e+00, -1.26040552e+00,  1.58862207e+00,
#         -2.00230803e+00],
#        [ 1.00000000e+00,  2.77188697e+00,  7.68335737e+00,
#          2.12973982e+01],
#        [ 1.00000000e+00, -1.26359007e+00,  1.59665986e+00,
#         -2.01752354e+00],
#        [ 1.00000000e+00, -2.19230812e+00,  4.80621490e+00,
#         -1.05367040e+01],
#        [ 1.00000000e+00, -1.57488893e+00,  2.48027515e+00,
#         -3.90615789e+00],
# ...

# %%
regression=LinearRegression()
regression.fit(X_train_poly,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(X_test_poly)
score=r2_score(Y_test,y_pred)
score
# Out:
# 1.0

# %%
## prediction of new data

x_new=np.linspace(-3,3,200).reshape(200,1)
x_new_poly=poly.transform(x_new)

# %%
x_new_poly
# Out:
# array([[ 1.00000000e+00, -3.00000000e+00,  9.00000000e+00],
#        [ 1.00000000e+00, -2.96984925e+00,  8.82000455e+00],
#        [ 1.00000000e+00, -2.93969849e+00,  8.64182723e+00],
#        [ 1.00000000e+00, -2.90954774e+00,  8.46546804e+00],
#        [ 1.00000000e+00, -2.87939698e+00,  8.29092700e+00],
#        [ 1.00000000e+00, -2.84924623e+00,  8.11820409e+00],
#        [ 1.00000000e+00, -2.81909548e+00,  7.94729931e+00],
#        [ 1.00000000e+00, -2.78894472e+00,  7.77821267e+00],
#        [ 1.00000000e+00, -2.75879397e+00,  7.61094417e+00],
#        [ 1.00000000e+00, -2.72864322e+00,  7.44549380e+00],
#        [ 1.00000000e+00, -2.69849246e+00,  7.28186157e+00],
#        [ 1.00000000e+00, -2.66834171e+00,  7.12004747e+00],
#        [ 1.00000000e+00, -2.63819095e+00,  6.96005151e+00],
#        [ 1.00000000e+00, -2.60804020e+00,  6.80187369e+00],
#        [ 1.00000000e+00, -2.57788945e+00,  6.64551400e+00],
#        [ 1.00000000e+00, -2.54773869e+00,  6.49097245e+00],
# ...

# %%
y_new=regression.predict(x_new_poly)

# %%
plt.scatter(x_new,y_new,color="red",label="predictions")
plt.scatter(X_train,Y_train,color="blue",label="training data")
plt.scatter(X_test,Y_test,color="green",label="ttesting data")

plt.legend()
plt.show()
