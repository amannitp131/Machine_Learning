# %%
## install pandas 

# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import pandas

import pandas as pd

# %%
## series in pandas 

# 1->from lists

data=[1,2,3,4,5]
series=pd.Series(data)
print(series)
print(type(series))


# 2-> from dictionary 


data={'a':1,'b':2,'c':3}
series2=pd.Series(data)
print(series2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10, 20, 30]
index = ['a', 'b', 'c']
series = pd.Series(data, index=index)
print(series)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## data frame in python 


# 1->create a data frame from a dictionary


data={
    'name':["akash","aman","ram"],
    'age':[10,20,30],
    'city':["banglore","noida","delhi"]

}



print(pd.DataFrame(data))
# Out:
#     name  age      city
# 0  akash   10  banglore
# 1   aman   20     noida
# 2    ram   30     delhi

# %%
## create a dataframe from a list of dictionaries 

people = [
    {'name': 'Alice', 'age': 30, 'city': 'New York'},
    {'name': 'Bob', 'age': 25, 'city': 'Los Angeles'},
    {'name': 'Charlie', 'age': 35, 'city': 'Chicago'},
    {'name': 'David', 'age': 28, 'city': 'Miami'},
    {'name': 'Eva', 'age': 22, 'city': 'San Francisco'}
]



people_df=pd.DataFrame(people)

print(people_df)
# Out:
#       name  age           city
# 0    Alice   30       New York
# 1      Bob   25    Los Angeles
# 2  Charlie   35        Chicago
# 3    David   28          Miami
# 4      Eva   22  San Francisco

# %%
## read a csv file using pandas 

iris_dataset =pd.read_csv("iris.csv")
iris_dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
## see top 5 row 

print(iris_dataset.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
## see the last 5 row 

print(iris_dataset.tail())
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
## see the first 10 row 

print(iris_dataset.head(10))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
## accessing data from the dataframe 
print(people_df['name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eva
# Name: name, dtype: object

# %%
## pick first row 

print(people_df.loc[0])
print("hii")
print(people_df.iloc[0])
# Out:
# name      Alice
# salary    10000
# Name: 0, dtype: object
# hii
# name      Alice
# salary    10000
# Name: 0, dtype: object

# %%
## accessing a specified element 

## means get the age of the element at index 1

print(people_df.at[2,'city'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\Desktop\summer break machine learning\myenv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 5
# ...

# %%
## using iat

people_df.iat[2,2]
# Out:
# 'Chicago'

# %%
## add a new column 

people_df['salary']=[10000,20000,30000,40000,50000]
people_df
# Out:
#       name  age           city  salary
# 0    Alice   30       New York   10000
# 1      Bob   25    Los Angeles   20000
# 2  Charlie   35        Chicago   30000
# 3    David   28          Miami   40000
# 4      Eva   22  San Francisco   50000

# %%
## remove a column 

people_df.drop(columns=['salary'],axis=1)
# Out:
#       name  age           city
# 0    Alice   30       New York
# 1      Bob   25    Los Angeles
# 2  Charlie   35        Chicago
# 3    David   28          Miami
# 4      Eva   22  San Francisco

# %%
people_df
# Out:
#       name  age           city  salary
# 0    Alice   30       New York   10000
# 1      Bob   25    Los Angeles   20000
# 2  Charlie   35        Chicago   30000
# 3    David   28          Miami   40000
# 4      Eva   22  San Francisco   50000

# %%
people_df
# Out:
#       name  age           city  salary
# 0    Alice   30       New York   10000
# 1      Bob   25    Los Angeles   20000
# 2  Charlie   35        Chicago   30000
# 3    David   28          Miami   40000
# 4      Eva   22  San Francisco   50000

# %%
## method 1->to permanently delete a column 

people_df=people_df.drop(columns=['age'],axis=1)
people_df
# Out:
#       name           city  salary
# 0    Alice       New York   10000
# 1      Bob    Los Angeles   20000
# 2  Charlie        Chicago   30000
# 3    David          Miami   40000
# 4      Eva  San Francisco   50000

# %%
## method 2-> using inplace 
people_df.drop(columns=['city'],axis=1,inplace=True)

# %%
people_df
# Out:
#       name  salary
# 0    Alice   10000
# 1      Bob   20000
# 2  Charlie   30000
# 3    David   40000
# 4      Eva   50000

# %%
data = {
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [30, 25, 35],
    'city': ['New York', 'Los Angeles', 'Chicago'],
    'salary': [70000, 80000, 90000]
}

data=pd.DataFrame(data)
print(data)
# Out:
#       name  age         city  salary
# 0    Alice   30     New York   70000
# 1      Bob   25  Los Angeles   80000
# 2  Charlie   35      Chicago   90000

# %%
## we want to increase everyones age by 1 

data['age']=data['age']+1

# %%
data
# Out:
#       name  age         city  salary
# 0    Alice   31     New York   70000
# 1      Bob   26  Los Angeles   80000
# 2  Charlie   36      Chicago   90000

# %%
## drop a row 

data.drop(0,inplace=True)

# %%
data
# Out:
#       name  age         city  salary
# 1      Bob   26  Los Angeles   80000
# 2  Charlie   36      Chicago   90000

# %%
# ATTRIBUTES 


print("DataTypes of attributes:/n",iris_dataset.dtypes)
# Out:
# DataTypes of attributes:/n Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
## statical summary of the data 


print("statical summary :\n" ,iris_dataset.describe())
# Out:
# statical summary :
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
## see the first five row of iris data set 

iris_dataset=pd.read_csv("iris.csv")
iris_dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
## check the last five records 

iris_dataset.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
## Handling Missing values->method to check no of missing values in any column 


iris_dataset.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
## read the sales data

df = pd.read_csv("sales_data_sample.csv", encoding='latin1')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
## find misiing values 


df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df_filled=df.fillna(0)

# %%
df_filled
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df_filled.isnull().any()
# Out:
# ORDERNUMBER         False
# QUANTITYORDERED     False
# PRICEEACH           False
# ORDERLINENUMBER     False
# SALES               False
# ORDERDATE           False
# STATUS              False
# QTR_ID              False
# MONTH_ID            False
# YEAR_ID             False
# PRODUCTLINE         False
# MSRP                False
# PRODUCTCODE         False
# CUSTOMERNAME        False
# PHONE               False
# ADDRESSLINE1        False
# ADDRESSLINE2        False
# CITY                False
# STATE               False
# POSTALCODE          False
# COUNTRY             False
# TERRITORY           False
# CONTACTLASTNAME     False
# CONTACTFIRSTNAME    False
# DEALSIZE            False
# dtype: bool

# %%
## read the sales data again 

df = pd.read_csv("sales_data_sample.csv", encoding='latin1')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
## check missing values 

df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
## fill the missing values with the mean of the column
# note->this is the way we are getting error because it is not a numerical value 
#  

df['POSTALCODE']=df['POSTALCODE'].fillna(df['POSTALCODE'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 5
#       1 ## fill the missing values with the mean of the column
#       2 # note->this is the way we are getting error because it is not a numerical value
#       3 #
# ----> 5 df['POSTALCODE']=df['POSTALCODE'].fillna(df['POSTALCODE'].mean())
#
# File c:\Users\HP\Desktop\summer break machine learning\myenv\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)   6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\HP\Desktop\summer break machine learning\myenv\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
# ...

# %%
df['POSTALCODE'].dtype
# Out:
# dtype('O')

# %%
iris_dataset.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
## renaming of columns 

iris_dataset.rename(columns={'SepalLengthCm':"sepal"},inplace=True)

# %%
iris_dataset.head()
# Out:
#    Id  sepal  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1    5.1           3.5            1.4           0.2  Iris-setosa
# 1   2    4.9           3.0            1.4           0.2  Iris-setosa
# 2   3    4.7           3.2            1.3           0.2  Iris-setosa
# 3   4    4.6           3.1            1.5           0.2  Iris-setosa
# 4   5    5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_dataset.dtypes
# Out:
# Id                 int64
# sepal            float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
## chnages datatypes of columns 


iris_dataset['PetalWidthCm']=iris_dataset['PetalWidthCm'].astype(int)

# %%
iris_dataset.dtypes
# Out:
# Id                 int64
# sepal            float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm       int64
# Species           object
# dtype: object

# %%
iris_dataset.head()
# Out:
#    Id  sepal  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1    5.1           3.5            1.4             0  Iris-setosa
# 1   2    4.9           3.0            1.4             0  Iris-setosa
# 2   3    4.7           3.2            1.3             0  Iris-setosa
# 3   4    4.6           3.1            1.5             0  Iris-setosa
# 4   5    5.0           3.6            1.4             0  Iris-setosa

# %%
## want to apply any function on a column 

## lets multiply petal length by 2 


iris_dataset['PetalLengthCm']=iris_dataset['PetalLengthCm'].apply(lambda x:x*2)

# %%
iris_dataset.head()
# Out:
#    Id  sepal  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1    5.1           3.5            2.8             0  Iris-setosa
# 1   2    4.9           3.0            2.8             0  Iris-setosa
# 2   3    4.7           3.2            2.6             0  Iris-setosa
# 3   4    4.6           3.1            3.0             0  Iris-setosa
# 4   5    5.0           3.6            2.8             0  Iris-setosa

# %%
mean_sepal = df.groupby('Species')[['sepal']].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 mean_sepal = df.groupby('Species')[['sepal']].mean()
#
# File c:\Users\HP\Desktop\summer break machine learning\myenv\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
iris_dataset.dtypes
# Out:
# Id                 int64
# sepal            float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm       int64
# Species           object
# dtype: object

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
average_order=df.groupby('YEAR_ID')['QUANTITYORDERED'].mean()
print(average_order)
# Out:
# YEAR_ID
# 2003    34.612000
# 2004    34.813383
# 2005    36.884937
# Name: QUANTITYORDERED, dtype: float64

# %%
sum_order=df.groupby(['YEAR_ID','MONTH_ID'])['QUANTITYORDERED'].sum()
print(sum_order)
# Out:
# YEAR_ID  MONTH_ID
# 2003     1            1357
#          2            1449
#          3            1755
#          4            1993
#          5            2017
#          6            1649
#          7            1725
#          8            1974
#          9            2510
#          10           5515
#          11          10179
#          12           2489
# 2004     1            3245
#          2            3061
#          3            1978
#          4            2077
#          5            2618
#          6            2971
#          7            3174
#          8            4564
#          9            3171
#          10           5483
#          11          10678
#          12           3804
# 2005     1            3395
#          2            3393
#          3            3852
#          4            2634
#          5            4357
# Name: QUANTITYORDERED, dtype: int64

# %%
## multiple aggregate function 

df_agg=df.groupby('YEAR_ID')['QUANTITYORDERED'].agg(['mean','median','sum','count'])
df_agg
# Out:
#               mean  median    sum  count
# YEAR_ID
# 2003     34.612000    34.0  34612   1000
# 2004     34.813383    35.0  46824   1345
# 2005     36.884937    36.0  17631    478

# %%
df1=pd.DataFrame({'key':['A','B','C'],'value':[1,2,3]})
df2=pd.DataFrame({'key':['A','D','E'],'value':[3,5,6]})

df3 = pd.merge(df1, df2, on="key", how="inner")
print(df3)
# Out:
#   key  value_x  value_y
# 0   A        1        3

# %%
df1=pd.DataFrame({'key':['A','B','C'],'value':[1,2,3]})
df2=pd.DataFrame({'key':['A','D','E'],'value':[3,5,6]})

df3 = pd.merge(df1, df2, on="key", how="outer")
print(df3)
# Out:
#   key  value_x  value_y
# 0   A      1.0      3.0
# 1   B      2.0      NaN
# 2   C      3.0      NaN
# 3   D      NaN      5.0
# 4   E      NaN      6.0

# %%
df1=pd.DataFrame({'key':['A','B','C'],'value':[1,2,3]})
df2=pd.DataFrame({'key':['A','D','E'],'value':[3,5,6]})

df3 = pd.merge(df1, df2, on="key", how="left")
print(df3)
# Out:
#   key  value_x  value_y
# 0   A        1      3.0
# 1   B        2      NaN
# 2   C        3      NaN

# %%
df1=pd.DataFrame({'key':['A','B','C'],'value':[1,2,3]})
df2=pd.DataFrame({'key':['A','D','E'],'value':[3,5,6]})

df3 = pd.merge(df1, df2, on="key", how="right")
print(df3)
# Out:
#   key  value_x  value_y
# 0   A      1.0        3
# 1   D      NaN        5
# 2   E      NaN        6

# %% [markdown]
# ## Reading data from different source

# %%
import pandas as pd
from io import StringIO
import json
data={
    "name":"akash chandra",
    "email":"akashc.ug23.cs@nitp.ac.in",
    "job profile":[{"title1":"web developer","title2":"machine learning"}]
}

df=pd.read_json(StringIO(json.dumps(data)))
df
# Out:
#             name                      email  \
# 0  akash chandra  akashc.ug23.cs@nitp.ac.in
#
#                                          job profile
# 0  {'title1': 'web developer', 'title2': 'machine...

# %%
## again convert it into a json 

df.to_json()
# Out:
# '{"name":{"0":"akash chandra"},"email":{"0":"akashc.ug23.cs@nitp.ac.in"},"job profile":{"0":{"title1":"web developer","title2":"machine learning"}}}'

# %%
df.to_json(orient="index")
# Out:
# '{"0":{"name":"akash chandra","email":"akashc.ug23.cs@nitp.ac.in","job profile":{"title1":"web developer","title2":"machine learning"}}}'

# %%
df.to_json(orient="records")
# Out:
# '[{"name":"akash chandra","email":"akashc.ug23.cs@nitp.ac.in","job profile":{"title1":"web developer","title2":"machine learning"}}]'

# %%
## read data from a url 

df=pd.read_csv("https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv")

# %%
df.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 393.8 kB/s eta 0:00:10
#    - -------------------------------------- 0.1/3.8 MB 819.2 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/3.8 MB 1.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.5/3.8 MB 2.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.1/3.8 MB 3.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.7/3.8 MB 5.4 MB/s eta 0:00:01
#    --------------------------- ------------ 2.6/3.8 MB 7.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 8.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# ...

# %%
## read html with pandas 

df=pd.read_html("https://www.fdic.gov/bank-failures/failed-bank-list")
df[0]
# Out:
#                                Bank Name               City         State  \
# 0                   Pulaski Savings Bank            Chicago      Illinois
# 1     The First National Bank of Lindsay            Lindsay      Oklahoma
# 2  Republic First Bank dba Republic Bank       Philadelphia  Pennsylvania
# 3                          Citizens Bank           Sac City          Iowa
# 4               Heartland Tri-State Bank            Elkhart        Kansas
# 5                    First Republic Bank      San Francisco    California
# 6                         Signature Bank           New York      New York
# 7                    Silicon Valley Bank        Santa Clara    California
# 8                      Almena State Bank             Almena        Kansas
# 9             First City Bank of Florida  Fort Walton Beach       Florida
#
#     Cert                Acquiring Institution      Closing Date  \
# 0  28611                      Millennium Bank  January 17, 2025
# ...

# %%
! pip install pandas openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/250.9 kB 393.8 kB/s eta 0:00:01
#    -------------- ------------------------ 92.2/250.9 kB 655.4 kB/s eta 0:00:01
#    ---------------------------------------  245.8/250.9 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 1.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel("excel.xlsx",engine="openpyxl")

# %%
df
# Out:
#       NAME  AGE
# 0    AKASH   20
# 1     JACK   32
# 2  ABHINAV   27
# 3   MRINAL   30

# %%
# !pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.to_pickle("df_excel")

# %%
pd.read_pickle("df_excel")
# Out:
#       NAME  AGE
# 0    AKASH   20
# 1     JACK   32
# 2  ABHINAV   27
# 3   MRINAL   30
